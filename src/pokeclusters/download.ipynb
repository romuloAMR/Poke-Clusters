# %% [markdown]
# # Data Download

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Download CSV

# %%
# !curl -L -o pokemonsv2.zip "https://www.kaggle.com/api/v1/datasets/download/takamasakato/pokemon-all-status-data"
# !unzip pokemonsv2.zip -d ../data/
# !rm -r pokemonsv2.zip

# %%
df1 = pd.read_csv("../data/Pokedex_Ver_SV2.csv")
df1.head()

# %%
df1.info()

# %%
# !curl -L -o pokemon.zip "https://www.kaggle.com/api/v1/datasets/download/jgassdfe/pokemon-dataset-of-gen-1-gen-9"
# !unzip pokemon.zip -d ../data/
# !rm -r pokemon.zip

# %%
df2 = pd.read_csv("../data/pokemon_data.csv")
df2.head()

# %%
df2.info()
